# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Load the word2vec and other required data here so that we don't have to run them again
import re
import xml.etree.ElementTree as ET
import argparse
import gensim
from diesel import ontology

gold_dataset = "data/input/predmap.txt"
trips_path = "../flaming-tyrion/lexicon/data/"
word2vec_path = "data/input/googlenews.bin"

TRIPS_ONTOLOGY = ontology.load_ontology(trips_path)
word2vec_model = gensim.models.Word2Vec.load_word2vec_format(
    word2vec_path, binary=True)

# %%
import skeleton
reload(skeleton)
# Out:
# <module 'skeleton' from 'skeleton/__init__.pyc'>

# %%
# Open the file and try to parse each line
for line in map(lambda x: x.strip(), open("data/input/random")):
    predicate = skeleton.LorePredicate("", "", line)
    success = predicate.parse(False)# Don't try to match with preexisting patternsd
    if success:
        print
        print
        print(line)
        print("Original parse")
        print("\t" + "\n\t".join(predicate.get_skeletons()))
        predicate.process_skeletons(word2vec_model, TRIPS_ONTOLOGY, False)
        print
        print("Improved parse")
        print("\t" + "\n\t".join(predicate.get_skeletons()))    
    else:
        print("Parse failed for ", line)
        print
# Out:
# Many-or-some parts are significant.
# Original parse
# 	(modifier :figure part)
# 	(have-property :formal primary :neutral part)
# 	(primary :figure part)
# 	(part :mod modifier)
# 	(sa_tell :content have-property)
# Not in light verb
# In light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(modifier :figure part)
# 	(have-property :formal primary :neutral part)
# 	(primary :figure part)
# 	(part :mod modifier)
# 	(sa_tell :content have-property)
#
#
# Much-or-some information is accurate.
# Original parse
# 	(modifier :figure information)
# 	(sa_tell :content have-property)
# 	(have-property :formal correct :neutral information)
# 	(information :mod modifier)
# 	(correct :figure information)
# Not in light verb
# In light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(modifier :figure information)
# 	(sa_tell :content have-property)
# 	(have-property :formal correct :neutral information)
# 	(information :mod modifier)
# 	(correct :figure information)
#
#
# Many males occasionally experience a nomination.
# Original parse
# 	(sometimes :figure have-experience)
# 	(have-experience :neutral male-person :formal acting :frequency sometimes)
# 	(sa_tell :content have-experience)
# 	(acting :figure male-person)
# Not in light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(sometimes :figure have-experience)
# 	(have-experience :neutral male-person :formal acting :frequency sometimes)
# 	(sa_tell :content have-experience)
# 	(acting :figure male-person)
#
#
# Many people like a proposition.
# Original parse
# 	(sa_identify :content person)
# 	(similar :figure person :ground proposal)
# 	(person :mod similar)
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(sa_identify :content person)
# 	(modifier :figure person :ground proposal)
# 	(person :mod similar)
#
#
# Many versions pertain to a male.
# Original parse
# 	(relation :neutral1 male-person :neutral version)
# 	(sa_tell :content relation)
# Not in light verb
#
# Improved parse
# 	(relation :neutral1 male-person :neutral version)
# 	(sa_tell :content relation)
#
#
# Militants may pertain to Taliban.
# Original parse
# 	(relation :neutral person :neutral1 organization)
# 	(sa_tell :content relation)
# Not in light verb
#
# Improved parse
# 	(relation :neutral person :neutral1 organization)
# 	(sa_tell :content relation)
# ('Parse failed for ', 'All-or-most males have as a part a column.')
#
#
#
# Many oil prices are high occasionally.
# Original parse
# 	(price :assoc-with natural-liquid-substance)
# 	(occasional :figure have-property)
# 	(have-property :neutral price :frequency occasional :formal high-val)
# 	(sa_tell :content have-property)
# 	(high-val :figure price)
# Not in light verb
# Not in light verb
# In light verb
# Not in light verb
#
# Improved parse
# 	(price :assoc-with natural-liquid-substance)
# 	(occasional :figure have-property)
# 	(have-property :neutral price :frequency occasional :formal high-val)
# 	(sa_tell :content have-property)
# 	(high-val :figure price)
#
#
# Many-or-some amounts are massive.
# Original parse
# 	(sa_tell :content have-property)
# 	(modifier :figure quantity)
# 	(quantity :mod modifier)
# 	(large :figure quantity)
# 	(have-property :neutral quantity :formal large)
# Not in light verb
# Not in light verb
# Not in light verb
# In light verb
#
# Improved parse
# 	(sa_tell :content have-property)
# 	(modifier :figure quantity)
# 	(quantity :mod modifier)
# 	(large :figure quantity)
# 	(have-property :neutral quantity :formal large)
#
#
# Many females possess a view.
# Original parse
# 	(possess :neutral1 mental-object :neutral female-person)
# 	(sa_tell :content possess)
# Not in light verb
#
# Improved parse
# 	(possess :neutral1 mental-object :neutral female-person)
# 	(sa_tell :content possess)
#
#
# Many people have relationships.
# Original parse
# 	(sa_tell :content have)
# 	(have :neutral1 relation :neutral person)
# In light verb
#
# Improved parse
# 	(sa_tell :content have)
# 	(have :neutral1 relation :neutral person)
#
#
# Many females occasionally note a proposition.
# Original parse
# 	(occasional :figure becoming-aware)
# 	(becoming-aware :agent female-person :neutral proposal :frequency occasional)
# 	(sa_tell :content becoming-aware)
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(occasional :figure becoming-aware)
# 	(becoming-aware :agent female-person :neutral proposal :frequency occasional)
# 	(sa_tell :content becoming-aware)
#
#
# Many-or-some females have a person as opponent.
# Original parse
# 	(female-person :mod modifier)
# 	(manner :ground person :figure have-experience)
# 	(modifier :figure female-person)
# 	(have-experience :manner manner :neutral person :experiencer female-person)
# 	(sa_tell :content have-experience)
# Not in light verb
# Not in light verb
# Not in light verb
# In light verb
#
# Improved parse
# 	(female-person :mod modifier)
# 	(event-time-rel :ground person :figure have-experience)
# 	(modifier :figure female-person)
# 	(have-experience :manner manner :neutral person :experiencer female-person)
# 	(sa_tell :content have-experience)
#
#
# Much-or-some television is national.
# Original parse
# 	(have-property :formal national-val :neutral device)
# 	(device :mod modifier)
# 	(sa_tell :content have-property)
# 	(modifier :figure device)
# 	(national-val :figure device)
# In light verb
# Not in light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(have-property :formal national-val :neutral device)
# 	(device :mod modifier)
# 	(sa_tell :content have-property)
# 	(modifier :figure device)
# 	(national-val :figure device)
#
#
# Many males occasionally experience advice.
# Original parse
# 	(have-experience :neutral male-person :frequency sometimes :formal proposal)
# 	(sometimes :figure have-experience)
# 	(proposal :figure male-person)
# 	(sa_tell :content have-experience)
# Not in light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(have-experience :neutral male-person :frequency sometimes :formal proposal)
# 	(sometimes :figure have-experience)
# 	(proposal :figure male-person)
# 	(sa_tell :content have-experience)
#
#
# Many males are active occasionally.
# Original parse
# 	(sa_tell :content have-property)
# 	(occasional :figure have-property)
# 	(have-property :neutral male-person :formal active :frequency occasional)
# 	(active :figure male-person)
# Not in light verb
# In light verb
# Not in light verb
#
# Improved parse
# 	(sa_tell :content have-property)
# 	(occasional :figure have-property)
# 	(have-property :neutral male-person :formal active :frequency occasional)
# 	(active :figure male-person)
#
#
# Many males occasionally play a role.
# Original parse
# 	(sa_tell :content play)
# 	(occasional :figure play)
# 	(play :affected utility :frequency occasional :agent male-person)
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(sa_tell :content play)
# 	(sometimes :figure play)
# 	(play :affected utility :frequency occasional :agent male-person)
#
#
# Many-or-some males are active.
# Original parse
# 	(sa_tell :content have-property)
# 	(active :figure male-person)
# 	(male-person :mod modifier)
# 	(have-property :neutral male-person :formal active)
# 	(modifier :figure male-person)
# Not in light verb
# Not in light verb
# In light verb
# Not in light verb
#
# Improved parse
# 	(sa_tell :content have-property)
# 	(active :figure male-person)
# 	(male-person :mod modifier)
# 	(have-property :neutral male-person :formal active)
# 	(modifier :figure male-person)
#
#
# Many-or-some females have an opponent.
# Original parse
# 	(sa_tell :content have)
# 	(female-person :mod modifier)
# 	(modifier :figure female-person)
# 	(have :neutral1 person :neutral female-person)
# Not in light verb
# Not in light verb
# In light verb
#
# Improved parse
# 	(sa_tell :content have)
# 	(female-person :mod modifier)
# 	(modifier :figure female-person)
# 	(have :neutral1 person :neutral female-person)
#
#
# Many-or-some banks are in a North American country.
# Original parse
# 	(have-property :neutral financial-institution :formal in-loc)
# 	(in-loc :ground country :figure financial-institution)
# 	(financial-institution :mod modifier)
# 	(modifier :figure financial-institution)
# 	(sa_tell :content have-property)
# 	(country :assoc-with nationality-val)
# In light verb
# Not in light verb
# Not in light verb
# Not in light verb
# Not in light verb
#
# Improved parse
# 	(have-property :neutral financial-institution :formal in-loc)
# 	(direction :ground country :figure financial-institution)
# 	(rely :mod modifier)
# 	(modifier :figure financial-institution)
# 	(sa_tell :content have-property)
# 	(country :assoc-with nationality-val)

# %%
sentence =  "Many lions occasionally experience a share."
predicate = skeleton.LorePredicate("", "", sentence)
success = predicate.parse(False)# Don't try to match with preexisting patternsd
predicate.print_skeletons()
print
print
predicate.process_skeletons(word2vec_model, TRIPS_ONTOLOGY, True)
print
print
predicate.print_skeletons()
# Out:
# 	 (sometimes :figure have-experience)
# 	 (have-experience :neutral nonhuman-animal :formal assets :frequency sometimes)
# 	 (sa_tell :content have-experience)
# 	 (assets :figure nonhuman-animal)
#
#
# Not in light verb
# Found in possible ontology list
# sometimes ( 0.0334398847499 )  ->  now_and_then: 0,once_in_a_while: 0,once_in_awhile: 0,sometimes: 0.133759538999
# sometimes ( 0.0334398847499 )  ->  now_and_then: 0,once_in_a_while: 0,once_in_awhile: 0,sometimes: 0.133759538999
#
# Sentence is  Many lions occasionally experience a share.
# occasionally  is the head word
# sometimes  is the head role
# sometimes  is the new selected head word
# ['experience']  are surrounding words
# Original skeleton :  (sometimes :figure have-experience)
# New skeleton :  (sometimes :figure have-experience)
#
# Not in light verb
# Found in possible ontology list
# have-experience ( 0.462522575297 )  ->  have: 0.462522575297
# have-experience ( 0.462522575297 )  ->  have: 0.462522575297
#
# Sentence is  Many lions occasionally experience a share.
# experience  is the head word
# have-experience  is the head role
# have-experience  is the new selected head word
# ['lion', 'share', 'occasionally']  are surrounding words
# Original skeleton :  (have-experience :neutral nonhuman-animal :formal assets :frequency sometimes)
# New skeleton :  (have-experience :neutral nonhuman-animal :formal assets :frequency sometimes)
#
# Not in light verb
# Found in possible ontology list
# share ( 0.320615305486 )  ->  share: 0.320615305486
# share-property ( 0 )  ->
# assets ( 0 )  ->
#
# Sentence is  Many lions occasionally experience a share.
# share  is the head word
# assets  is the head role
# share  is the new selected head word
# ['lion']  are surrounding words
# Original skeleton :  (assets :figure nonhuman-animal)
# New skeleton :  (share :figure nonhuman-animal)
#
#
#
# 	 (sometimes :figure have-experience)
# 	 (have-experience :neutral nonhuman-animal :formal assets :frequency sometimes)
# 	 (sa_tell :content have-experience)
# 	 (share :figure nonhuman-animal)
